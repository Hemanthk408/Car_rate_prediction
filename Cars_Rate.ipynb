# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemanthk408/Car_rate_prediction/blob/main/Cars_Rate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


B=pd.read_json("/content/car_details_bengalur.json")
C=pd.read_json("/content/car_details_chennai.json")
N=pd.read_json("/content/car_details_New_Delhi.json")
J=pd.read_json("/content/car_details_jaipur.json")
P=pd.read_json("/content/car_details_pune.json")

pd.set_option("display.max_columns",None)

# Define the required columns
columns_to_keep = ['title', 'price', 'location', 'Registration Year', 'Insurance',
                   'Fuel Type','Kms Driven', 'RTO', 'Ownership']

# Select only required columns from each dataframe
df1 = B[columns_to_keep]
df2 = C[columns_to_keep]
df3 = N[columns_to_keep]
df4 = J[columns_to_keep]
df5=P[columns_to_keep]

# Merge all dataframes
merged_df = pd.concat([df1, df2, df3, df4,df5], ignore_index=True)

# Save the final dataframe
merged_df.to_csv('merged_data.csv', index=False)

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/merged_data.csv")
df
# Out:
#                                                   title       price  \
# 0               2021 Tata Nexon XZA Plus (O) AMT Diesel  ₹9.97 Lakh
# 1                          2021 Kia Sonet HTX Turbo iMT  ₹9.98 Lakh
# 2                               2023 Audi Q5 Technology    ₹72 Lakh
# 3                       2020 Hyundai i20 Asta Turbo iMT  ₹8.39 Lakh
# 4                            2015 Maruti Celerio VXI AT  ₹3.65 Lakh
# ...                                                 ...         ...
# 2327                            2024 Audi Q7 Technology    ₹87 Lakh
# 2328                             2021 Nissan Magnite XE  ₹5.07 Lakh
# 2329  2013 Audi A4 2.0 TDI Premium Sport Limited Edi...  ₹7.99 Lakh
# 2330                      2013 Hyundai i20 Petrol Magna  ₹2.71 Lakh
# 2331                       2019 Renault Triber RXL BSIV  ₹4.25 Lakh
#
#                     location Registration Year      Insurance Fuel Type  \
# 0     Malleswaram, Bangalore          Jan 2021  Comprehensive    Diesel
# 1       Yelahanka, Bangalore          Feb 2021  Comprehensive    Petrol
# 2       R T Nagar, Bangalore          Dec 2023  Comprehensive    Petrol
# 3       Yelahanka, Bangalore          Nov 2020  Comprehensive    Petrol
# 4      Btm Layout, Bangalore          Dec 2015  Comprehensive    Petrol
# ...                      ...               ...            ...       ...
# 2327             Baner, Pune               NaN        Expired    Petrol
# 2328           Wagholi, Pune          Oct 2021  Comprehensive    Petrol
# 2329           Yerwada, Pune          Dec 2013  Comprehensive    Diesel
# 2330             Wakad, Pune          Apr 2013  Comprehensive    Petrol
# 2331        Thathawade, Pune          Oct 2019        Expired    Petrol
#
#       Kms Driven         RTO     Ownership
# 0     12,758 Kms   Bangalore   First Owner
# 1      9,424 Kms   Bangalore   First Owner
# 2      3,000 Kms   Bangalore   First Owner
# 3     13,539 Kms      Mysore   First Owner
# 4     57,742 Kms   Bangalore  Second Owner
# ...          ...         ...           ...
# 2327   5,000 Kms         NaN           NaN
# 2328  14,276 Kms  Aurangabad   First Owner
# 2329  75,000 Kms         Pen   Third Owner
# 2330  48,008 Kms      Nashik   First Owner
# 2331  13,774 Kms      Mumbai   First Owner
#
# [2332 rows x 9 columns]

# %%
df["location"]=df["location"].str.split(',').str[1]

# %%
df=pd.read_excel("/content/ml_dl.xlsx")

# %%
df
# Out:
#            city      ft      km transmission  ownerNo      oem  \
# 0       Kolkata  Petrol   70000    Automatic        3   Toyota
# 1       Kolkata  Petrol   23981       Manual        1   Datsun
# 2       Kolkata  Petrol    7100    Automatic        1  Renault
# 3       Kolkata  Petrol   71574       Manual        2  Hyundai
# 4       Kolkata  Diesel   50000    Automatic        2     Audi
# ...         ...     ...     ...          ...      ...      ...
# 8364  Bangalore  Diesel  156039       Manual        2   Toyota
# 8365  Bangalore  Petrol   56000       Manual        2   Maruti
# 8366  Bangalore  Petrol   42000       Manual        2    Honda
# 8367  Bangalore  Diesel   93003       Manual        1  Hyundai
# 8368  Bangalore  Petrol   36000    Automatic        2  Hyundai
#
#                   model  modelYear             variantName    price  \
# 0          Toyota Camry       2014                  Hybrid   975000
# 1         Datsun RediGO       2017                T Option   266000
# 2         Renault Kiger       2021                 RXT AMT   595000
# 3           Hyundai i20       2011              1.2 Sportz   223000
# 4               Audi Q3       2014  35 TDI Quattro Premium  1200000
# ...                 ...        ...                     ...      ...
# 8364    Toyota Fortuner       2012                  4x4 MT  1648999
# 8365         Maruti SX4       2008               Zxi BSIII   330000
# 8366         Honda Brio       2014                    S MT   425000
# 8367        Hyundai i20       2018      1.4 Asta Dual Tone   750000
# 8368  Hyundai Grand i10       2017          Asta Option AT   675000
#
#       Registration Year Insurance Validity  Seats
# 0                  2014        Third Party      5
# 1                  2017      Comprehensive      5
# 2                  2021      Comprehensive      5
# 3                  2012        Third Party      5
# 4                  2014        Third Party      5
# ...                 ...                ...    ...
# 8364               2012      Comprehensive      7
# 8365               2008        Third Party      5
# 8366               2014      Comprehensive      5
# 8367               2018      Comprehensive      5
# 8368               2017      Comprehensive      5
#
# [8369 rows x 13 columns]

# %%
df=df.drop(["bt","Engine Displacement"],axis=1)

# %%
df.isnull().sum()
# Out:
# city                  0
# ft                    0
# km                    0
# transmission          0
# ownerNo               0
# oem                   0
# model                 0
# modelYear             0
# variantName           0
# price                 0
# Registration Year     0
# Insurance Validity    0
# Seats                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   city                8369 non-null   object
#  1   ft                  8369 non-null   object
#  2   km                  8369 non-null   int64
#  3   transmission        8369 non-null   object
#  4   ownerNo             8369 non-null   int64
#  5   oem                 8369 non-null   object
#  6   model               8369 non-null   object
#  7   modelYear           8369 non-null   int64
#  8   variantName         8369 non-null   object
#  9   price               8369 non-null   int64
#  10  Registration Year   8369 non-null   int64
#  11  Insurance Validity  8369 non-null   object
#  12  Seats               8369 non-null   int64
# dtypes: int64(6), object(7)
# memory usage: 850.1+ KB

# %%
df.to_csv("carrate.csv")

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder=OrdinalEncoder()

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['city', 'ft', 'transmission', 'oem', 'model', 'variantName',
#        'Insurance Validity'],
#       dtype='object')

# %%
for i in df.select_dtypes(include='object').columns:
  df[i]=encoder.fit_transform(df[[i]])

# %%
df
# Out:
#       city   ft      km  transmission  ownerNo   oem  model  modelYear  \
# 0      5.0  4.0   70000           0.0        3  30.0  279.0       2014
# 1      5.0  4.0   23981           1.0        1   4.0   39.0       2017
# 2      5.0  4.0    7100           0.0        1  27.0  239.0       2021
# 3      5.0  4.0   71574           1.0        2   9.0   90.0       2011
# 4      5.0  1.0   50000           0.0        2   0.0    7.0       2014
# ...    ...  ...     ...           ...      ...   ...    ...        ...
# 8364   0.0  1.0  156039           1.0        2  30.0  285.0       2012
# 8365   0.0  4.0   56000           1.0        2  20.0  177.0       2008
# 8366   0.0  4.0   42000           1.0        2   8.0   61.0       2014
# 8367   0.0  1.0   93003           1.0        1   9.0   90.0       2018
# 8368   0.0  4.0   36000           0.0        2   9.0   77.0       2017
#
#       variantName    price  Registration Year  Insurance Validity  Seats
# 0          1213.0   975000               2014                 4.0      5
# 1          1683.0   266000               2017                 2.0      5
# 2          1458.0   595000               2021                 2.0      5
# 3           149.0   223000               2012                 4.0      5
# 4           692.0  1200000               2014                 4.0      5
# ...           ...      ...                ...                 ...    ...
# 8364        741.0  1648999               2012                 2.0      7
# 8365       2082.0   330000               2008                 4.0      5
# 8366       1504.0   425000               2014                 2.0      5
# 8367        208.0   750000               2018                 2.0      5
# 8368        864.0   675000               2017                 2.0      5
#
# [8369 rows x 13 columns]

# %%
df.corr()
# Out:
#                         city        ft        km  transmission   ownerNo  \
# city                1.000000 -0.014920 -0.020517      0.097957 -0.058144
# ft                 -0.014920  1.000000 -0.165490      0.077116 -0.044848
# km                 -0.020517 -0.165490  1.000000      0.065439  0.115419
# transmission        0.097957  0.077116  0.065439      1.000000  0.046777
# ownerNo            -0.058144 -0.044848  0.115419      0.046777  1.000000
# oem                 0.004477 -0.019222  0.015448      0.057014 -0.040402
# model              -0.004007 -0.040365  0.023288      0.040397 -0.030762
# modelYear          -0.005974  0.055197 -0.245030     -0.196946 -0.390012
# variantName         0.051079  0.065258 -0.049889      0.097972 -0.062918
# price              -0.075789 -0.181315 -0.077351     -0.422600 -0.120489
# Registration Year  -0.007783  0.056964 -0.243921     -0.196864 -0.390402
# Insurance Validity  0.049108 -0.014626  0.036390      0.120762  0.114257
# Seats               0.005295 -0.299714  0.074924      0.008312  0.010594
#
#                          oem     model  modelYear  variantName     price  \
# city                0.004477 -0.004007  -0.005974     0.051079 -0.075789
# ft                 -0.019222 -0.040365   0.055197     0.065258 -0.181315
# km                  0.015448  0.023288  -0.245030    -0.049889 -0.077351
# transmission        0.057014  0.040397  -0.196946     0.097972 -0.422600
# ownerNo            -0.040402 -0.030762  -0.390012    -0.062918 -0.120489
# oem                 1.000000  0.988939   0.091536    -0.002543 -0.034547
# model               0.988939  1.000000   0.074859    -0.023676 -0.007771
# modelYear           0.091536  0.074859   1.000000     0.084525  0.299459
# variantName        -0.002543 -0.023676   0.084525     1.000000 -0.037512
# price              -0.034547 -0.007771   0.299459    -0.037512  1.000000
# Registration Year   0.090081  0.073661   0.996792     0.083713  0.299549
# Insurance Validity  0.037936  0.033188  -0.085389    -0.015299 -0.148510
# Seats               0.134449  0.132111   0.005254     0.049300  0.083875
#
#                     Registration Year  Insurance Validity     Seats
# city                        -0.007783            0.049108  0.005295
# ft                           0.056964           -0.014626 -0.299714
# km                          -0.243921            0.036390  0.074924
# transmission                -0.196864            0.120762  0.008312
# ownerNo                     -0.390402            0.114257  0.010594
# oem                          0.090081            0.037936  0.134449
# model                        0.073661            0.033188  0.132111
# modelYear                    0.996792           -0.085389  0.005254
# variantName                  0.083713           -0.015299  0.049300
# price                        0.299549           -0.148510  0.083875
# Registration Year            1.000000           -0.088406  0.002323
# Insurance Validity          -0.088406            1.000000  0.000951
# Seats                        0.002323            0.000951  1.000000

# %%
df.columns
# Out:
# Index(['city', 'ft', 'km', 'transmission', 'ownerNo', 'oem', 'model',
#        'modelYear', 'variantName', 'price', 'Registration Year',
#        'Insurance Validity', 'Seats'],
#       dtype='object')

# %%
#hypotheses
continues=["km","transmission","price","modelYear",]
categories=["city","ft","ownerNo","oem","model","Insurance Validity","Seats","variantName","Registration Year"]


from scipy import stats

def two_sample(d1,d2):
  t=0
  f=0
  for i in  range(31):
    sample1=d1.sample(frac=0.03)
    sample2=d2.sample(frac=0.03)
    t_test,p_value=stats.ttest_ind(sample1,sample2)
    if p_value < 0.055:
      f=f+1
    else:
      t=t+1
  if t>f:
    return True
  else:
    return False

#defining function for categories vs categories
def chisqare_cat_vs_cat(d1,d2):
  return True if stats.chi2_contingency(pd.crosstab(d1,d2))[1] < 0.055 else False

def annova_test(d1,d2):
  group=df[d2].unique()
  data={}
  for i in group:
    data[i]=df[d1][df[d2]==i]
  f_value,p_value=stats.f_oneway(*[i for i in data.values()])
  if p_value < 0.055:
    return False
  else:
    return True

final={}
for i in df.columns:
  final[i]={}
  for j in df.columns:
    if (i in continues) and (j in continues):
      result=two_sample(df[i],df[j])
    elif  (i in continues) and (j in categories):
      result=annova_test(i,j)
    elif (i in categories) and (j in continues):
      result=annova_test(j,i)
    elif (i in categories) and (j in categories):
      result=chisqare_cat_vs_cat(df[i],df[j])
    if result:
      final[i][j]=1
    else:
      final[i][j]=0

# %%
df2=pd.DataFrame(final)

# %%
df2
# Out:
#                     city  ft  km  transmission  ownerNo  oem  model  \
# city                   1   1   0             0        0    0      0
# ft                     1   1   0             0        1    1      1
# km                     0   0   1             0        0    0      0
# transmission           0   0   0             1        0    0      0
# ownerNo                0   1   0             0        1    1      1
# oem                    0   1   0             0        1    1      1
# model                  0   1   0             0        1    1      1
# modelYear              0   0   0             0        0    0      0
# variantName            0   1   0             0        1    1      1
# price                  0   0   0             0        0    0      0
# Registration Year      0   1   0             0        1    1      1
# Insurance Validity     0   1   0             0        1    1      0
# Seats                  1   1   0             0        1    1      1
#
#                     modelYear  variantName  price  Registration Year  \
# city                        0            0      0                  0
# ft                          0            1      0                  1
# km                          0            0      0                  0
# transmission                0            0      0                  0
# ownerNo                     0            1      0                  1
# oem                         0            1      0                  1
# model                       0            1      0                  1
# modelYear                   1            0      0                  0
# variantName                 0            1      0                  1
# price                       0            0      1                  0
# Registration Year           0            1      0                  1
# Insurance Validity          0            0      0                  1
# Seats                       0            1      0                  1
#
#                     Insurance Validity  Seats
# city                                 0      1
# ft                                   1      1
# km                                   0      0
# transmission                         0      0
# ownerNo                              1      1
# oem                                  1      1
# model                                0      1
# modelYear                            0      0
# variantName                          0      1
# price                                0      0
# Registration Year                    1      1
# Insurance Validity                   1      0
# Seats                                0      1

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from scipy.stats import kurtosis
from scipy.stats import norm

# %%
for i in df.columns:                                   #skew -0.5 to 0.5 and kurtosis -3 to 3
  print(i,kurtosis(df[i]),df[i].skew())
  sns.distplot(df[i],fit=norm)
  plt.show()
# Out:
# city -1.2260777996642187 0.08516102958191378
# <ipython-input-21-86cb625a601c>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i],fit=norm)
# ft -1.4273342996346279 -0.7250062978730587
# <ipython-input-21-86cb625a601c>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i],fit=norm)
# km 3546.0112865544097 50.3925297710879
# <ipython-input-21-86cb625a601c>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i],fit=norm)
# transmission -1.0051530812942984 -0.9975989429297407
# <ipython-input-21-86cb625a601c>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i],fit=norm)
# ownerNo 4.364804946588134 1.8981794523293787
# <ipython-input-21-86cb625a601c>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i],fit=norm)
# oem -1.0437018275257686 0.11191498760585111
# <ipython-input-21-86cb625a601c>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i],fit=norm)
# model -0.8477836622585269 0.37449702873387464
# <ipython-input-21-86cb625a601c>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i],fit=norm)
# modelYear 1.7715948126796173 -0.9118985966325266
# <ipython-input-21-86cb625a601c>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i],fit=norm)
# variantName -1.268707889357442 -0.2511525854045037
# <ipython-input-21-86cb625a601c>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i],fit=norm)
# price 197.00776948798855 10.004739391860278
# <ipython-input-21-86cb625a601c>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i],fit=norm)
# Registration Year 1.7874120299043055 -0.9250373683458096
# <ipython-input-21-86cb625a601c>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i],fit=norm)
# Insurance Validity -1.5728382652673178 -0.32316832650466837
# <ipython-input-21-86cb625a601c>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i],fit=norm)
# Seats 7.665414389602514 2.5905175887283503
# <ipython-input-21-86cb625a601c>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i],fit=norm)

# %%
for i in df.columns:
  print(i,df[i].skew())
  plt.show
# Out:
# city 0.08516102958191378
# ft -0.7250062978730587
# km 50.3925297710879
# transmission -0.9975989429297407
# ownerNo 1.8981794523293787
# oem 0.11191498760585111
# model 0.37449702873387464
# modelYear -0.9118985966325266
# variantName -0.2511525854045037
# price 10.004739391860278
# Registration Year -0.9250373683458096
# Insurance Validity -0.32316832650466837
# Seats 2.5905175887283503

# %%
for i in continues:
  print(i,df[i].skew(),df[i].kurtosis())
# Out:
# km -1.3036960766754453 3.7867724811114853
# transmission -0.9972295866116471 -1.0057736231328562
# price 0.3820880526041389 1.2635078485658622
# modelYear -0.9120718623427764 1.776198422247894

# %%
df[df["km"]==0].drop("km",axis=1)
# Out:
#       city   ft  km  transmission  ownerNo   oem  model  modelYear  \
# 1943   4.0  4.0   0           1.0        1  20.0  184.0       2015
# 3799   3.0  1.0   0           1.0        3  29.0  260.0       2007
#
#       variantName   price  Registration Year  Insurance Validity  Seats
# 1943       1823.0  350000               2015                 3.0      5
# 3799       1250.0   20161               2007                 3.0      5

# %%
df.drop(df.loc[df["km"]==0].index,inplace=True)

# %%
df[df["km"]==0]
# Out:
# Empty DataFrame
# Columns: [city, ft, km, transmission, ownerNo, oem, model, modelYear, variantName, price, Registration Year, Insurance Validity, Seats]
# Index: []

# %%
import plotly.express as px

# %%
#lmbda = 0 = log(x)

#lmbda = 0.5 = sqrt(x)

#lmbda = -0.5 = 1/sqrt(x)

#lmbda = 1 = x

#lmbda = -1 = 1/x

#lmbda = 2 = x**2

#lmbda = -2 = 1/x**2

# %%
data=["price","km"]             #kurtosis   -3 to 3
from scipy import stats         #skew       -1 to 1
method=[0,0.5,-0.5,1,-1,2,-2]
for i in method:
  for j in data:
    print(i,j)
    print("skewness",pd.DataFrame(stats.boxcox(df[j],lmbda=i)).skew().values,"kurtosis",pd.DataFrame(stats.boxcox(df[j],lmbda=i)).kurtosis().values)
# Out:
# 0 price
# skewness [0.38208805] kurtosis [1.26350785]
# 0 km
# skewness [-1.30369608] kurtosis [3.78677248]
# 0.5 price
# skewness [2.77946308] kurtosis [15.18221214]
# 0.5 km
# skewness [2.77698738] kurtosis [65.01972887]
# -0.5 price
# skewness [-1.74284837] kurtosis [6.63844132]
# -0.5 km
# skewness [-9.66412376] kurtosis [179.9856263]
# 1 price
# skewness [10.00431163] kurtosis [197.10291265]
# 1 km
# skewness [50.39751881] kurtosis [3548.32142857]
# -1 price
# skewness [-4.92400693] kurtosis [39.26301893]
# -1 km
# skewness [-34.90163636] kurtosis [1526.3998361]
# 2 price
# skewness [42.7567587] kurtosis [2171.21321032]
# 2 km
# skewness [88.83371162] kurtosis [8023.08207138]
# -2 price
# skewness [0.] kurtosis [0.]
# -2 km
# skewness [-61.48672589] kurtosis [4306.27885548]

# %%
df["km"]=stats.boxcox(df["km"],lmbda=0)

# %%
df["price"]=stats.boxcox(df["price"],lmbda=0)

# %%
for i in co:                                   #skew -0.5 to 0.5 and kurtosis -3 to 3
  print(i,kurtosis(df[i]),df[i].skew())
# Out:
# city -1.2261245661015674 0.08552123102258206
# ft -1.4270355474215357 -0.7252018586043977
# km 3.783792921225154 -1.3036960766754453
# transmission -1.005889704911951 -0.9972295866116471
# ownerNo 4.371799486270704 1.8990239667042752
# oem -1.043529878647948 0.11223355606344497
# model -0.8472665819460263 0.37492986010062723
# modelYear 1.774420151754569 -0.9120718623427764
# variantName -1.2689545651068155 -0.2508806496256993
# price 1.262035903395569 0.3820880526041389
# Registration Year 1.7902848554683706 -0.925218948042542
# Insurance Validity -1.5730591061293626 -0.32331398573206005
# Seats 7.662583305005976 2.590082496205511

# %%
for i in continues:
  print(i,df[i].skew(),df[i].kurtosis())
# Out:
# km -1.3036960766754453 3.7867724811114853
# transmission -0.9972295866116471 -1.0057736231328562
# price 0.3820880526041389 1.2635078485658622
# modelYear -0.9120718623427764 1.776198422247894

# %%
x=df.drop("price",axis=1)
y=df["price"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (6695, 12)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(n_estimators=200,max_depth=52,random_state=0,min_samples_split=3).fit(x_train,y_train)
y_pred=model.predict(x_test)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 1076496098595.0175
# 214526.68202239118
# 0.5960483294925819

# %%
from sklearn.linear_model import LinearRegression
model2=LinearRegression().fit(x_train,y_train)
y_pred=model2.predict(x_test)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 2240532999323.239
# 556382.7096616807
# 0.1592472568318073

# %%
from sklearn.ensemble import ExtraTreesRegressor
model3=ExtraTreesRegressor().fit(x_train,y_train)
y_pred=model3.predict(x_test)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 1118195879694.4922
# 235128.32446833933
# 0.5804006218446757

# %%
from sklearn.ensemble import ExtraTreesRegressor
model6=ExtraTreesRegressor().fit(x_train,y_train)
y_pred=model6.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))

# %%
from sklearn.ensemble import RandomForestRegressor
model10 = RandomForestRegressor(n_estimators=100,criterion='squared_error',max_depth=2, random_state=0)
result=model10.fit(x_train, y_train)
y_pred = model10.predict(x_test)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 2125662553361.7302
# 527487.065395335
# 0.20235201921658974

# %%
#overfit to general -hypertune
from sklearn.ensemble import RandomForestRegressor
model2=RandomForestRegressor(n_estimators=2,max_depth=12,random_state=22,min_samples_split=3).fit(x_train,y_train)
y_pred=model2.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))

# %%
import pickle

# %%
with open ("Carsmodel.pkl","wb") as f:
  pickle.dump(model,f)

# %%
pickle.dump(model,open("model.pkl","wb"))

# %%
with open("carmodel1.pkl","wb") as f:
  pickle.dump(model10,f)

# %% [markdown]
# #file mearge
